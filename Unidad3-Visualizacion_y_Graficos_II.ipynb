# %% [markdown]
# # Intérprete de LOGO para Python
#
# LOGO es un lenguaje de programación cuya finalidad era enseñar a programar mediante la generación de gráficos.
#
# Existen varios módulos de Python que reproducen el funcionamiento de LOGO, sin embargo, aquí usaremos el módulo llamado **ColabTurtlePlus** por ser completamente compatible con Colab.
#
# La distribución de Python incluida en Colab no incluye este módulo, por lo que para usarlo debemos instalarlo de la misma forma en como instalaríamos un módulo de Python en una computadora local, es decir, utilizando el comando **pip install**.
#
# La siguiente instrucción instala el módulo *ColabTurtlePlus* en la sesión de Colab:

# %%
# !pip install ColabTurtlePlus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ColabTurtlePlus in /usr/local/lib/python3.8/dist-packages (2.0.1)

# %% [markdown]
# Podemos comprobar que se ha instalado correctamente importando el módulo

# %%
import ColabTurtlePlus.Turtle as logo

# %% [markdown]
# La documentación de este módulo podemos consultarla en el siguiente [link](https://larryriddle.agnesscott.org/ColabTurtlePlus/documentation2.html). Sin embargo, existen algunos comandos básicos que nos permitirán dibujar con este módulo:
#
# * initializeTurtle( )
# * penup( )
# * pendown( )
# * forward( )
# * left( )
# * right( )
#
# Utilizaremos **initializeTurtle** antes de cada dibujo. Podemos imaginar que este módulo es un simulador para dibujar, por lo que hay dos instrucciones, a saber, **penup** y **pendown**, las cuales se refieren a *levantar la pluma del papel* y *colocar la pluma sobre el papel*, respectivamente; de manera que podemos posicionar una pluma virtual en cualquier coordenada, pero sólo dibujará algo si antes de mover la pluma hacemos un **pendown**. Veamos un ejemplo de cómo trazar una línea horizontal de 100 unidades:

# %%
import ColabTurtlePlus.Turtle as logo

logo.initializeTurtle()

logo.pendown()
logo.forward(100)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="410.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="410.0" y1="300.0" x2="420.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="420.0" y1="300.0" x2="430.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="430.0" y1="300.0" x2="440.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="440.0" y1="300.0" x2="450.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="450.0" y1="300.0" x2="460.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="460.0" y1="300.0" x2="470.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="470.0" y1="300.0" x2="480.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="480.0" y1="300.0" x2="490.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="490.0" y1="300.0" x2="500.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90,500.0,300.0) translate(500.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
#                       begin="0s" dur="0.01s"
#                       repeatCount="1"
#                       additive="sum"
#                       fill="freeze"
#                 /><animateTransform attributeName="transform"
#                     type="rotate"
#                     from="0 0 0" to ="120 0 0"
#                     begin="one.end" dur="0.006666666666666666s"
#                     repeatCount="1"
#                     additive="sum"
#                     fill="freeze"
#                 /></g>
#       </svg>

# %% [markdown]
# También podemos dibujar una circunferencia

# %%
import ColabTurtlePlus.Turtle as logo

logo.initializeTurtle()

logo.pendown()


radius=50
extent=360 # 360 grados para un circulo completo
steps=30
logo.circle(radius, extent, steps)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 50 50 0 0 0 412.941 298.296" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 412.941 298.296 A 50 50 0 0 0 425.0 293.301" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 425.0 293.301 A 50 50 0 0 0 435.355 285.355" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 435.355 285.355 A 50 50 0 0 0 443.301 275.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 443.301 275.0 A 50 50 0 0 0 448.296 262.941" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 448.296 262.941 A 50 50 0 0 0 450.0 250.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 450.0 250.0 A 50 50 0 0 0 448.296 237.059" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 448.296 237.059 A 50 50 0 0 0 443.301 225.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 443.301 225.0 A 50 50 0 0 0 435.355 214.645" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 435.355 214.645 A 50 50 0 0 0 425.0 206.699" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 425.0 206.699 A 50 50 0 0 0 412.941 201.704" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 412.941 201.704 A 50 50 0 0 0 400.0 200.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 200.0 A 50 50 0 0 0 387.059 201.704" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 387.059 201.704 A 50 50 0 0 0 375.0 206.699" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 375.0 206.699 A 50 50 0 0 0 364.645 214.645" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 364.645 214.645 A 50 50 0 0 0 356.699 225.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 356.699 225.0 A 50 50 0 0 0 351.704 237.059" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 351.704 237.059 A 50 50 0 0 0 350.0 250.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 350.0 250.0 A 50 50 0 0 0 351.704 262.941" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 351.704 262.941 A 50 50 0 0 0 356.699 275.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 356.699 275.0 A 50 50 0 0 0 364.645 285.355" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 364.645 285.355 A 50 50 0 0 0 375.0 293.301" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 375.0 293.301 A 50 50 0 0 0 387.059 298.296" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 387.059 298.296 A 50 50 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/>
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90.0,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
#                       begin="0s" dur="0.01s"
#                       repeatCount="1"
#                       additive="sum"
#                       fill="freeze"
#                 /><animateTransform attributeName="transform"
#                     type="rotate"
#                     from="0 0 0" to ="120 0 0"
#                     begin="one.end" dur="0.006666666666666666s"
#                     repeatCount="1"
#                     additive="sum"
#                     fill="freeze"
#                 /></g>
#       </svg>

# %% [markdown]
# Como siguiente ejemplo vamos a fijar un tamaño de lienzo y sobre él vamos a dibujar 100 círculos cuya posición y radio serán elegidas al azar.
#
# El módulo **random** nos es de ayuda para generar números al azar en un intervalo. Veamos qué hace la siguiente celda:

# %%
import random as rnd
x=rnd.uniform(1.15,2.6)
print(x)
# Out:
# 1.4365266024435785

# %% [markdown]
# Si utilizamos un ciclo **for** y la función anterior, podemos elegir al azar tantos números como necesitemos. Además, podemos utilizar tres veces la función **uniform** para elegir el radio y las coordenadas x,y determinando un círculo de radio arbitrario y en una posición al azar:

# %%
import random as rnd

import ColabTurtlePlus.Turtle as logo
logo.initializeTurtle()

# La siguiente linea solo acelera la animacion
logo.speed(13)

# Elegimos un ancho del lienzo
ancho=500
largo=300
logo.setup(ancho,largo)

# Elegimos al azar la posicion y radio del circulo
x=rnd.uniform(-ancho/2,ancho/2)
y=rnd.uniform(-largo/2,largo/2)
max_radio=10 # este valor es el tamano maximo del radio
radio=rnd.uniform(1,max_radio)



extent=360 
steps=30

# Colocamos a la "tortuga" en la posicion elegida al azar,
# "colocamos la pluma sobre el papel" y dibujamos un circulo
logo.jumpto(x,y)
logo.pendown()
logo.circle(radio,extent,steps)
# Out:
#       <svg width="500" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 305.373 207.04 A 7.141106420566427 7.141106420566427 0 0 0 307.221 206.797" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 307.221 206.797 A 7.141106420566427 7.141106420566427 0 0 0 308.943 206.084" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 308.943 206.084 A 7.141106420566427 7.141106420566427 0 0 0 310.422 204.949" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 310.422 204.949 A 7.141106420566427 7.141106420566427 0 0 0 311.557 203.47" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 311.557 203.47 A 7.141106420566427 7.141106420566427 0 0 0 312.27 201.748" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 312.27 201.748 A 7.141106420566427 7.141106420566427 0 0 0 312.513 199.9" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 312.513 199.9 A 7.141106420566427 7.141106420566427 0 0 0 312.27 198.052" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 312.27 198.052 A 7.141106420566427 7.141106420566427 0 0 0 311.557 196.33" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 311.557 196.33 A 7.141106420566427 7.141106420566427 0 0 0 310.422 194.851" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 310.422 194.851 A 7.141106420566427 7.141106420566427 0 0 0 308.943 193.716" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 308.943 193.716 A 7.141106420566427 7.141106420566427 0 0 0 307.221 193.003" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 307.221 193.003 A 7.141106420566427 7.141106420566427 0 0 0 305.373 192.76" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 305.373 192.76 A 7.141106420566427 7.141106420566427 0 0 0 303.525 193.003" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 303.525 193.003 A 7.141106420566427 7.141106420566427 0 0 0 301.803 193.716" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 301.803 193.716 A 7.141106420566427 7.141106420566427 0 0 0 300.324 194.851" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 300.324 194.851 A 7.141106420566427 7.141106420566427 0 0 0 299.189 196.33" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 299.189 196.33 A 7.141106420566427 7.141106420566427 0 0 0 298.476 198.052" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 298.476 198.052 A 7.141106420566427 7.141106420566427 0 0 0 298.233 199.9" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 298.233 199.9 A 7.141106420566427 7.141106420566427 0 0 0 298.476 201.748" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 298.476 201.748 A 7.141106420566427 7.141106420566427 0 0 0 299.189 203.47" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 299.189 203.47 A 7.141106420566427 7.141106420566427 0 0 0 300.324 204.949" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 300.324 204.949 A 7.141106420566427 7.141106420566427 0 0 0 301.803 206.084" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 301.803 206.084 A 7.141106420566427 7.141106420566427 0 0 0 303.525 206.797" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 303.525 206.797 A 7.141106420566427 7.141106420566427 0 0 0 305.373 207.04" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/>
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90.0,305.373,207.04) translate(305.373, 207.04)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
#                       begin="0s" dur="0.01s"
#                       repeatCount="1"
#                       additive="sum"
#                       fill="freeze"
#                 /><animateTransform attributeName="transform"
#                     type="rotate"
#                     from="0 0 0" to ="120 0 0"
#                     begin="one.end" dur="0.006666666666666666s"
#                     repeatCount="1"
#                     additive="sum"
#                     fill="freeze"
#                 /></g>
#       </svg>

# %% [markdown]
# En la siguient celda vamos a repetir el mismo código de la celda anterior pero dentro de un ciclo **for** que repetirá el proceso 100 veces:

# %%
import ColabTurtlePlus.Turtle as logo
logo.initializeTurtle()

logo.speed(13)

import random as rnd

ancho=500
largo=300
logo.setup(ancho,largo)

for i in range(100):
  x=rnd.uniform(-ancho/2,ancho/2)
  y=rnd.uniform(-largo/2,largo/2)
  max_radio=10
  radio=rnd.uniform(1,max_radio)



  extent=360 # 360 grados para un circulo completo
  steps=30


  logo.jumpto(x,y)
  logo.pendown()
  logo.circle(radio,extent,steps)
# Out:
#       <svg width="500" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 441.199 88.25 A 4.193727642211585 4.193727642211585 0 0 0 441.199 79.863" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 441.199 79.863 A 4.193727642211585 4.193727642211585 0 0 0 441.199 88.25" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 456.598 193.384 A 5.407229719224321 5.407229719224321 0 0 0 456.598 182.57" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 456.598 182.57 A 5.407229719224321 5.407229719224321 0 0 0 456.598 193.384" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 77.439 77.855 A 4.080311118924188 4.080311118924188 0 0 0 77.439 69.694" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 77.439 69.694 A 4.080311118924188 4.080311118924188 0 0 0 77.439 77.855" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 408.157 70.404 A 9.926419985159457 9.926419985159457 0 0 0 408.157 50.551" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 408.157 50.551 A 9.926419985159457 9.926419985159457 0 0 0 408.157 70.404" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 97.062 130.95 A 7.443536152893785 7.443536152893785 0 0 0 97.062 116.063" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 97.062 116.063 A 7.443536152893785 7.443536152893785 0 0 0 97.062 130.95" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 343.448 19.478 A 7.5782621623633455 7.5782621623633455 0 0 0 343.448 4.321" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 343.448 4.321 A 7.5782621623633455 7.5782621623633455 0 0 0 343.448 19.478" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 481.672 215.93 A 3.3645794337689003 3.3645794337689003 0 0 0 481.672 209.201" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 481.672 209.201 A 3.3645794337689003 3.3645794337689003 0 0 0 481.672 215.93" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 137.461 43.951 A 3.4649072830098184 3.4649072830098184 0 0 0 137.461 37.021" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 137.461 37.021 A 3.4649072830098184 3.4649072830098184 0 0 0 137.461 43.951" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 304.658 171.105 A 6.799303886089679 6.799303886089679 0 0 0 304.658 157.506" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 304.658 157.506 A 6.799303886089679 6.799303886089679 0 0 0 304.658 171.105" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 192.69 22.217 A 1.077369272841525 1.077369272841525 0 0 0 192.69 20.062" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 192.69 20.062 A 1.077369272841525 1.077369272841525 0 0 0 192.69 22.217" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 128.833 109.896 A 2.899029624861143 2.899029624861143 0 0 0 128.833 104.098" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 128.833 104.098 A 2.899029624861143 2.899029624861143 0 0 0 128.833 109.896" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 123.241 284.474 A 4.721207817330399 4.721207817330399 0 0 0 123.241 275.032" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 123.241 275.032 A 4.721207817330399 4.721207817330399 0 0 0 123.241 284.474" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 2.219 135.637 A 7.021847424968508 7.021847424968508 0 0 0 2.219 121.593" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 2.219 121.593 A 7.021847424968508 7.021847424968508 0 0 0 2.219 135.637" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 18.52 172.711 A 6.4631292881710625 6.4631292881710625 0 0 0 18.52 159.785" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 18.52 159.785 A 6.4631292881710625 6.4631292881710625 0 0 0 18.52 172.711" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 359.208 59.03 A 4.163437419014615 4.163437419014615 0 0 0 359.208 50.703" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 359.208 50.703 A 4.163437419014615 4.163437419014615 0 0 0 359.208 59.03" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 377.566 205.848 A 5.442155200709991 5.442155200709991 0 0 0 377.566 194.964" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 377.566 194.964 A 5.442155200709991 5.442155200709991 0 0 0 377.566 205.848" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 303.541 11.808 A 3.6946262099327902 3.6946262099327902 0 0 0 303.541 4.419" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 303.541 4.419 A 3.6946262099327902 3.6946262099327902 0 0 0 303.541 11.808" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 177.079 49.164 A 7.385148461957051 7.385148461957051 0 0 0 177.079 34.394" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 177.079 34.394 A 7.385148461957051 7.385148461957051 0 0 0 177.079 49.164" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 337.215 19.199 A 6.308602456411341 6.308602456411341 0 0 0 337.215 6.582" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 337.215 6.582 A 6.308602456411341 6.308602456411341 0 0 0 337.215 19.199" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 473.664 221.248 A 2.6149215300116744 2.6149215300116744 0 0 0 473.664 216.018" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 473.664 216.018 A 2.6149215300116744 2.6149215300116744 0 0 0 473.664 221.248" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 273.553 174.457 A

# %% [markdown]
# ¿Existe alguna manera de evitar que los círculos se traslapen?
# <br>
# **Sí!**
# <br>
# Dos círculos se traslapan si la distancia entre sus centros es menor a la suma de ambos radios. Usaremos una lista para almacenar la información de los círculos conforme vayamos sorteando las posiciones y radios de los círculos,y agregaremos dicho círculo a la lista sólo si no se traslapa con los círculos anteriores, nos aseguraremos que no hay traslape pidiendo que la distancia entre los centros sea (por ejempllo) mayor al doble de la suma de los radios.
#
# Podemos identificar a partir de aquí, que utilizaremos lista, condicionales y un ciclo while para asegurarnos en generar 100 círculos:

# %%
import math
import random as rnd
import ColabTurtlePlus.Turtle as logo

logo.initializeTurtle()
logo.speed(13)

ancho=500
largo=300
max_radio=50
extent=360
steps=30

circulos=[]
logo.setup(ancho,largo)

radio=rnd.uniform(1,max_radio)
x=rnd.uniform(-ancho/2,ancho/2)
y=rnd.uniform(-largo/2,largo/2)

circulos.append([radio,x,y])

while len(circulos)<100:
  interseccion=0

  radio=rnd.uniform(1,max_radio)
  x=rnd.uniform(-ancho/2,ancho/2)
  y=rnd.uniform(-largo/2,largo/2)

  for circulo in circulos:
    RADIO,posx,posy=circulo
    if math.sqrt((posx-x)**2+(posy-y)**2)<2*(RADIO+radio):
      interseccion=1
  if interseccion==0:
      circulos.append([radio,x,y])
for circulo in circulos:
  radio,x,y=circulo
  logo.jumpto(x,y)
  logo.pendown()
  logo.circle(radio,extent)
# Out:
#       <svg width="500" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 375.01 139.529 A 28.371939588617476 28.371939588617476 0 0 0 375.01 82.785" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 375.01 82.785 A 28.371939588617476 28.371939588617476 0 0 0 375.01 139.529" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 169.07 83.56 A 28.110477250766333 28.110477250766333 0 0 0 169.07 27.339" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 169.07 27.339 A 28.110477250766333 28.110477250766333 0 0 0 169.07 83.56" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 63.805 111.5 A 9.301223894579442 9.301223894579442 0 0 0 63.805 92.898" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 63.805 92.898 A 9.301223894579442 9.301223894579442 0 0 0 63.805 111.5" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 25.605 239.057 A 15.875194929554313 15.875194929554313 0 0 0 25.605 207.307" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 25.605 207.307 A 15.875194929554313 15.875194929554313 0 0 0 25.605 239.057" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 128.869 256.584 A 31.763409525150706 31.763409525150706 0 0 0 128.869 193.057" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 128.869 193.057 A 31.763409525150706 31.763409525150706 0 0 0 128.869 256.584" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 314.397 195.569 A 12.281475624305617 12.281475624305617 0 0 0 314.397 171.006" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 314.397 171.006 A 12.281475624305617 12.281475624305617 0 0 0 314.397 195.569" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 467.396 60.654 A 29.87935577901652 29.87935577901652 0 0 0 467.396 0.895" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 467.396 0.895 A 29.87935577901652 29.87935577901652 0 0 0 467.396 60.654" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 275.579 65.144 A 6.063223665322899 6.063223665322899 0 0 0 275.579 53.018" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 275.579 53.018 A 6.063223665322899 6.063223665322899 0 0 0 275.579 65.144" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 3.263 141.421 A 2.954724960184032 2.954724960184032 0 0 0 3.263 135.512" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 3.263 135.512 A 2.954724960184032 2.954724960184032 0 0 0 3.263 141.421" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 236.902 104.507 A 1.1720605906773431 1.1720605906773431 0 0 0 236.902 102.163" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 236.902 102.163 A 1.1720605906773431 1.1720605906773431 0 0 0 236.902 104.507" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 455.979 245.628 A 2.2863219279578044 2.2863219279578044 0 0 0 455.979 241.055" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 455.979 241.055 A 2.2863219279578044 2.2863219279578044 0 0 0 455.979 245.628" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 350.825 52.076 A 15.692243707797687 15.692243707797687 0 0 0 350.825 20.692" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 350.825 20.692 A 15.692243707797687 15.692243707797687 0 0 0 350.825 52.076" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 395.315 227.758 A 11.870114002257345 11.870114002257345 0 0 0 395.315 204.018" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 395.315 204.018 A 11.870114002257345 11.870114002257345 0 0 0 395.315 227.758" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 2.264 177.242 A 1.2799455933789625 1.2799455933789625 0 0 0 2.264 174.682" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 2.264 174.682 A 1.2799455933789625 1.2799455933789625 0 0 0 2.264 177.242" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 213.951 167.019 A 6.989057913876001 6.989057913876001 0 0 0 213.951 153.041" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 213.951 153.041 A 6.989057913876001 6.989057913876001 0 0 0 213.951 167.019" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 426.844 183.773 A 3.9326614045962147 3.9326614045962147 0 0 0 426.844 175.908" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 426.844 175.908 A 3.9326614045962147 3.9326614045962147 0 0 0 426.844 183.773" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 259.504 210.598 A 1.6992279014766276 1.6992279014766276 0 0 0 259.504 207.2" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 259.504 207.2 A 1.6992279014766276 1.6992279014766276 0 0 0 259.504 210.598" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 457.029 226.295 A 6.558612360050565 6.558612360050565 0 0 0 457.029 213.178" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 457.029 213.178 A 6.558612360050565 6.558612360050565 0 0 0 457.029 226.295" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 63.659 163.459 A 14.208443426522237 14.208443426522237 0 0 0 63.659 135.042" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 63.659 135.042 A 14.208443426522237 14.208443426522237 0 0 0 63.659 163.459" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 268.997 293.0 A 37.14727165692959 37.14727165692959 0 0 0 268.997 218.705" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 268.997 218.705 A 37.14727165692959 37.14727165692959 0 0 0 268.997 293.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke

# %% [markdown]
# Veamos otro ejemplo donde además cambiaremos el color y guardaremos el gráfico como archivo:

# %%
import ColabTurtlePlus.Turtle as logo

logo.initializeTurtle()
logo.speed(13)

ancho=500
largo=300

logo.setup(ancho,largo)


logo.penup()
logo.color(0,0,255)
for i in range(150):
  logo.pendown()
  logo.forward(i)
  logo.left(91)

logo.saveSVG('espiral_00.svg', False) # False si no queremos que el grafico incluya al cursor/tortuga
# Out:
#       <svg width="500" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="250.0" y1="150.0" x2="250.0" y2="150.0" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="250.0" y1="150.0" x2="249.983" y2="149.0" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="249.983" y1="149.0" x2="247.984" y2="149.07" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="247.984" y1="149.07" x2="248.141" y2="152.066" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="248.141" y1="152.066" x2="252.131" y2="151.787" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="252.131" y1="151.787" x2="251.695" y2="146.806" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="251.695" y1="146.806" x2="245.728" y2="147.433" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="245.728" y1="147.433" x2="246.581" y2="154.381" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="246.581" y1="154.381" x2="254.503" y2="153.268" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="254.503" y1="153.268" x2="253.095" y2="144.379" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="253.095" y1="144.379" x2="243.247" y2="146.115" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="243.247" y1="146.115" x2="245.346" y2="156.913" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="245.346" y1="156.913" x2="257.084" y2="154.418" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="257.084" y1="154.418" x2="254.16" y2="141.751" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="254.16" y1="141.751" x2="240.576" y2="145.138" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="240.576" y1="145.138" x2="244.458" y2="159.627" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="244.458" y1="159.627" x2="259.838" y2="155.217" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="259.838" y1="155.217" x2="254.868" y2="138.96" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="254.868" y1="138.96" x2="237.749" y2="144.522" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="237.749" y1="144.522" x2="243.935" y2="162.487" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="243.935" y1="162.487" x2="262.729" y2="155.647" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="262.729" y1="155.647" x2="255.203" y2="136.042" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="255.203" y1="136.042" x2="234.805" y2="144.283" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="234.805" y1="144.283" x2="243.792" y2="165.455" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="243.792" y1="165.455" x2="265.717" y2="155.693" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="265.717" y1="155.693" x2="255.152" y2="133.035" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="255.152" y1="133.035" x2="231.783" y2="144.433" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="231.783" y1="144.433" x2="244.041" y2="168.49" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="244.041" y1="168.49" x2="268.764" y2="155.345" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="268.764" y1="155.345" x2="254.705" y2="129.981" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="254.705" y1="129.981" x2="228.724" y2="144.981" stroke-linecap="round" style="stroke:rgb(0,0,255);stroke-width:1" /><line x1="228.724" y1="144.981" x2="244.69" y2="171.553" stroke-linecap="round" style="stroke:rgb(0,0,255);str ...

# %%
# !ls
# Out:
# espiral_00.svg	sample_data

# %% [markdown]
# Veamos un ejemplo más donde generaremos un fractal

# %%
import ColabTurtlePlus.Turtle as logo



def star(a, order):
    if order > 0:
        for t in [60, -120, 60, 0]:
            star(a/3,order-1)
            logo.left(t)
    else:
        logo.forward(a)

logo.initializeTurtle()
logo.speed(13)

star(250,4)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="403.086" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="403.086" y1="300.0" x2="404.629" y2="297.327" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="404.629" y1="297.327" x2="406.172" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="406.172" y1="300.0" x2="409.258" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="409.258" y1="300.0" x2="410.801" y2="297.327" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="410.801" y1="297.327" x2="409.258" y2="294.654" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="409.258" y1="294.654" x2="412.344" y2="294.654" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="412.344" y1="294.654" x2="413.887" y2="291.981" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="413.887" y1="291.981" x2="415.43" y2="294.654" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="415.43" y1="294.654" x2="418.516" y2="294.654" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="418.516" y1="294.654" x2="416.973" y2="297.327" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="416.973" y1="297.327" x2="418.516" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="418.516" y1="300.0" x2="421.602" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="421.602" y1="300.0" x2="423.145" y2="297.327" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="423.145" y1="297.327" x2="424.688" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="424.688" y1="300.0" x2="427.774" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="427.774" y1="300.0" x2="429.317" y2="297.327" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="429.317" y1="297.327" x2="427.774" y2="294.654" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="427.774" y1="294.654" x2="430.86" y2="294.654" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="430.86" y1="294.654" x2="432.403" y2="291.981" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="432.403" y1="291.981" x2="430.86" y2="289.308" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="430.86" y1="289.308" x2="427.774" y2="289.308" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="427.774" y1="289.308" x2="429.317" y2="286.635" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="429.317" y1="286.635" x2="427.774" y2="283.962" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="427.774" y1="283.962" x2="430.86" y2="283.962" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="430.86" y1="283.962" x2="432.403" y2="281.289" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="432.403" y1="281.289" x2="433.946" y2="283.962" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="433.946" y1="283.962" x2="437.032" y2="283.962" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="437.032" y1="283.962" x2="438.575" y2="281.289" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="438.575" y1="281.289" x2="437.032" y2="278.616" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="437.032" y1="278.616" x2="440.118" y2="278.616" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="440.118" y1="278.616" x2="441.661" y2="275.943" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="441.661" y1="275.943" x2="443.204" y2="278.616" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="443.204" y1="278.616" x2="446.29" y2="278.616" stroke-linecap="round" style="stroke:black;strok ...

# %% [markdown]
# ### Funciones en Python
#
# En el ejercicio anterior introdujimos una nueva instrucción de Python: **def**
#
# Esta instrucción se utiliza en python para definir funciones personalizadas, veamos unos ejemplos:

# %%
"""
En este ejemplo definiremos una funcion que devuelve el mismo numero
que le pasemos como argumento siempre y cuando este sea mayor o igual a 10,
y en caso contrario, devuelve el 0

Notemos que la instruccion return es la que se encarga de devolver el
resultado una vez termina la ejecucion de la la funcion
"""

def mi_funcion(x):
  if x<10:
    resultado=0
  else:
    resultado=x
  return resultado


print(mi_funcion(5))
# Out:
# 0

# %% [markdown]
# A través de funciones podemos definir conjuntos de instrucciones con cierto nivel de dificultad. Por ejemplo, veamos cómo se define la siguiente función:
#
# <center>
# $f(x)=\begin{cases} n/2 \, \,\,\,\,\,si\,x\,es\,par\\ 3x-1 \, \,\,\,\,si\, x\, es\, impar\end{cases}$
# </center>
#
# Para determinar si un número es par podemos dividirlo entre dos y verificar que el residuo de la división es cero, esto lo podemos hacer con una función llamada *módulo* que se denota por **$\%$**,veamos el ejemplo:

# %%
def f(x):
  if x%2==0:
    return x/2
  else:
    return 3*x-1


print(f(4))
# Out:
# 2.0
