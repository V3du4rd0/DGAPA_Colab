# %% [markdown]
# # Módulo **Plotly**
#
# Este módulo permite crear gráficos interactivos.
#
# ### Ejemplo: Superficies en el espacio
#
# En este ejemplo vamos a graficar la superficie descritapor la siguiente parametrización (Superfiice de Enneper)
#
# <center>
# $x(u,v)=u\,(1-\frac{u^2}{3}+v^2)/3$
# <br><br>
# $y(u,v)= -v\,(1-\frac{v^2}{3}+u^2)/3$
# <br><br>
# $z(u,v)=(u^2-v^2)/3$
# </center>
#
# con el siguiente dominio
# <br>
# <center>
# $-2\leq u \leq 2$
# <br><br>
# $-2\leq v \leq 2$
# </center>
#
# De manera similar a otros módulos, por ejemplo matplotlib, para generar esta superficie es necesario partir de un mallado. En la siguiente celda estamos dividiendo el dominio [-2,2] en 100 partes, y la parametrización la hemos escrito siguiendo las operaciones matemáticas en Python:

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


import numpy as np

u, v = np.mgrid[-2:2:100j, -2:2:100j]
x = u*(1-u**2/3+v**2)/3
y = -v*(1-v**2/3+u**2)/3
z = (u**2-v**2)/3

fig = make_subplots(rows=1, cols=2,
                    specs=[[{'is_3d': True}, {'is_3d': True}]]
                    )

fig.add_trace(go.Surface(x=x, y=y, z=z, colorbar_x=-0.07), 1, 1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="51c8195d-5327-4191-bd14-3a3dfdd6da42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51c8195d-5327-4191-bd14-3a3dfdd6da42")) {                    Plotly.newPlot(                        "51c8195d-5327-4191-bd14-3a3dfdd6da42",                        [{"colorbar":{"x":-0.07},"x":[[-2.4444444444444446,-2.337788661020984,-2.2333095262388194,-2.1310070400979497,-2.0308812025983745,-1.9329320137400945,-1.8371594735231096,-1.74356358194742,-1.6521443390130255,-1.562901744719926,-1.4758357990681226,-1.3909465020576135,-1.308233853688399,-1.2276978539604804,-1.1493385028738563,-1.073155800428528,-0.9991497466244939,-0.9273203414617557,-0.8576675849403123,-0.7901914770601639,-0.7248920178213106,-0.6617692072237525,-0.6008230452674899,-0.5420535319525216,-0.4854606672788491,-0.43104445124647145,-0.3788048838553888,-0.32874196510560133,-0.280855694997109,-0.23514607352991193,-0.19161310070400983,-0.15025677651940272,-0.1110771009760908,-0.074074074074074,-0.03924769581335227,-0.006597966193925682,0.023875114784205675,0.05217154712104207,0.07829133081658336,0.10223446587082956,0.12400095228378061,0.1435907900554366,0.16100397918579734,0.1762405196748631,0.18930041152263374,0.20018365472910926,0.20889024929428968,0.21542019521817501,0.21977349250076517,0.22195014114206027,0.22195014114206027,0.21977349250076514,0.21542019521817493,0.20889024929428965,0.20018365472910915,0.18930041152263366,0.17624051967486296,0.16100397918579726,0.14359079005543648,0.12400095228378039,0.10223446587082942,0.07829133081658309,0.05217154712104192,0.023875114784205342,-0.006597966193926015,-0.03924769581335245,-0.0740740740740744,-0.11107710097609103,-0.15025677651940317,-0.19161310070401005,-0.23514607352991246,-0.2808556949971095,-0.3287419651056016,-0.3788048838553894,-0.4310444512464717,
:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2447 (2.4K) [text/csv]
# Saving to: ‘pollution.csv’
#
# pollution.csv       100%[===================>]   2.39K  --.-KB/s    in 0s
#
# 2023-01-10 10:16:35 (88.2 MB/s) - ‘pollution.csv’ saved [2447/2447]

# %%
# !ls
# Out:
# glass.csv  pollution.csv  sample_data

# %% [markdown]
# Visualizaremos una pequeña muestra del archivo que acabamos de descargar usando el módulo **pandas**, el cual sirve para trabajar con este tipo de archivos

# %%
import pandas as pd

df = pd.read_csv('pollution.csv')

df.head()
# Out:
#           City   "SO2 mg/cm"   "Temp F"   "Manufacturing Plants"   "1970 Pop"  \
# 0  Albuquerque            11       56.8                       46          244
# 1       Albany            46       47.6                       44          116
# 2      Atlanta            24       61.5                      368          497
# 3    Baltimore            47       55.0                      625          905
# 4      Buffalo            11       47.1                      391          463
#
#     "Wind mph"   "Precip inches"   "Precip days"
# 0          8.9              7.77              58
# 1          8.8             33.36             135
# 2          9.1             48.34             115
# 3          9.6             41.31             111
# 4         12.4             36.11             166

# %% [markdown]
# Ahora usaremos Plotly para graficar la temperatura por ciudad directamente del archivo que acabamos de leer con *pandas*

# %%
import plotly.express as px

fig = px.line(df, x = 'City', y =' "Temp F"', title='Temp por Ciudad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="027ef254-9540-4455-8f91-e26fb4cf234c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("027ef254-9540-4455-8f91-e26fb4cf234c")) {                    Plotly.newPlot(                        "027ef254-9540-4455-8f91-e26fb4cf234c",                        [{"hovertemplate":"City=%{x}<br> \"Temp F\"=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Albuquerque","Albany","Atlanta","Baltimore","Buffalo","Charleston","Chicago","Cincinnati","Cleveland","Columbus","Dallas","Denver","DesMoines","Detroit","Hartford","Houston","Indianapolis","Jacksonville","KansasCity","LittleRock","Louisville","Memphis","Miami","Milwaukee","Minneapolis","Nashville","NewOrleans","Norfork","Omaha","Philadelphia","Phoenix","Pittsburgh","Providence","Richmond","SaltLakeCity","SanFrancisco","Seattle","StLouis","WashingtonDC","Wilmington","Wichita"],"xaxis":"x","y":[56.8,47.6,61.5,55.0,47.1,55.2,50.6,54.0,49.7,51.5,66.2,51.9,49.0,49.9,49.1,68.9,52.3,68.4,54.5,61.0,55.6,61.6,75.5,45.7,43.5,59.4,68.3,59.3,51.5,54.6,70.3,50.4,50.0,57.8,51.0,56.7,51.1,55.9,57.3,54.0,56.6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...

# %% [markdown]
# ### Curvas de nivel
#
# En el siguiente ejemplo graficaremos las curvas de nivel de una función de la forma $z=f(x,y)$.

# %%
import plotly.graph_objects as go

x_grid = np.linspace(-25, 25, 20)
y_grid = np.linspace(-25, 25,20)


[X, Y] = np.meshgrid(x_grid, y_grid)

Z = X**2-Y**2

fig = go.Figure(data =
	go.Contour(x = x_grid, y = y_grid, z = Z))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c29db082-94a8-41a4-83c8-26311c642e80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c29db082-94a8-41a4-83c8-26311c642e80")) {                    Plotly.newPlot(                        "c29db082-94a8-41a4-83c8-26311c642e80",                        [{"x":[-25.0,-22.36842105263158,-19.736842105263158,-17.105263157894736,-14.473684210526315,-11.842105263157894,-9.210526315789473,-6.578947368421051,-3.94736842105263,-1.3157894736842088,1.3157894736842124,3.9473684210526336,6.578947368421055,9.21052631578948,11.842105263157897,14.473684210526315,17.10526315789474,19.736842105263165,22.368421052631582,25.0],"y":[